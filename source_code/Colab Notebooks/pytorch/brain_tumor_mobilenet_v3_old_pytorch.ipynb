# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Adas/src
from adas import Adas
# Out:
# /content/drive/My Drive/Adas/src

# %%
import matplotlib.pyplot as plt
from torchvision import datasets, models, transforms
import helper
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
import torch, torchvision
from torch.utils.data import DataLoader
import time
from torchsummary import summary
import numpy as np
import os

from PIL import Image

# %%
IMAGE_SIZE = 256
batch_size = 16

DATADIR_TRAIN = "/content/drive/My Drive/DetectBrainTumor/data_1_19052021/T2_Train/"
DATADIR_VAL = "/content/drive/My Drive/DetectBrainTumor/data_1_19052021/T2_Val/"

# %%
# Applying Transforms to the Data
train_transform = transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

test_transform = transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

# %%
train_data = datasets.ImageFolder(DATADIR_TRAIN, transform=train_transform)                                       
val_data = datasets.ImageFolder(DATADIR_VAL, transform=test_transform)

#Data Loading
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True)

# %%
classes = ('YES', 'NO')

# %%
train_data_size = len(train_data)
test_data_size = len(val_data)

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # functions to show an image


# def imshow(img):
#     img = img / 2 + 0.5     # unnormalize
#     npimg = img.numpy()
#     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#     plt.show()


# # get some random training images
# dataiter = iter(train_loader)
# images, labels = dataiter.next()

# # show images
# imshow(torchvision.utils.make_grid(images))
# # print labels
# print(' '.join('%5s' % classes[labels[j]] for j in range(2)))

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Load pretrained ResNet50 Model
model_class = models.mobilenet_v2(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# HBox(children=(FloatProgress(value=0.0, max=14212972.0), HTML(value='')))

# %%
model_class
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): ConvBNActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): ConvBNActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %%
# Change the final layer of ResNet50 Model for Transfer Learning
# inputs = model_class._classifier.in_features

model_class._classifier = nn.Sequential(
    nn.Linear(1280, 128),
    nn.ReLU(),
    nn.Dropout(0.3),
    nn.Flatten(),
    nn.Dropout(0.5),
    nn.Linear(128, 2), # Since 2 possible outputs
    nn.LogSoftmax(dim=1) # For using NLLLoss()
)

# Convert model to be used on GPU
model_class = model_class.to(device)

# %%
def train_and_validate(model, scheduler, loss_criterion, optimizer, epochs):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_loss = 100000.0
    best_epoch = None
    flag = 0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(train_loader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

        
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(val_loader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)
                # if not j%100:
                #   print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
        if valid_loss < best_loss:
            best_loss = valid_loss
            best_epoch = epoch

        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_valid_loss = valid_loss/test_data_size 
        avg_valid_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss - {:.4f}, Accuracy - {:.4f}%, Validation : Loss - {:.4f}, Accuracy - {:.4f}%, Time: {:.4f}s".format(epoch+1, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start))

        #reduce lr
        
        if avg_valid_acc*100 > 88:
          flag = 1

        if flag == 1:
          scheduler.step(avg_valid_loss)
        
        print('Epoch-{0} learning rate: {1}'.format(epoch, optimizer.param_groups[0]['lr']))

        # Save if the model has best accuracy till now
        # torch.save(model, 'model_'+str(epoch)+'.pt')
        # optimizer.epoch_step(epoch)       
    return model, history, best_epoch

# %%
# Define Optimizer and Loss Function
# loss_func = nn.NLLLoss()
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(params=list(model_class.parameters()), lr=1e-5)

# %%
num_epochs = 100

start = time.time()

# trained_model, history, best_epoch = train_and_validate(model_class, loss_func, optimizer, num_epochs)

# scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20,35], gamma=0.1)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=torch.exp(-0.1))

# lambda1 = lambda epoch: torch.exp(-1) ** epoch
# scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor= 0.95, patience=3, threshold=0.0001, threshold_mode='abs')

trained_model, history, best_epoch = train_and_validate(model_class, scheduler, loss_func, optimizer, num_epochs)

end = time.time()
# torch.save(history, 'history.pt')
# Out:
# Epoch: 1/100
# Epoch : 001, Training: Loss - 9.1562, Accuracy - 0.3690%, Validation : Loss - 10.4412, Accuracy - 0.0000%, Time: 230.6056s
# Epoch-0 learning rate: 1e-05
# Epoch: 2/100
# Epoch : 002, Training: Loss - 7.2599, Accuracy - 4.0590%, Validation : Loss - 8.2591, Accuracy - 0.8368%, Time: 16.4204s
# Epoch-1 learning rate: 1e-05
# Epoch: 3/100
# Epoch : 003, Training: Loss - 5.2128, Accuracy - 23.2472%, Validation : Loss - 7.1234, Accuracy - 17.1548%, Time: 16.3810s
# Epoch-2 learning rate: 1e-05
# Epoch: 4/100
# Epoch : 004, Training: Loss - 3.4231, Accuracy - 53.5055%, Validation : Loss - 5.6843, Accuracy - 40.1674%, Time: 16.5603s
# Epoch-3 learning rate: 1e-05
# Epoch: 5/100
# Epoch : 005, Training: Loss - 2.3529, Accuracy - 70.4797%, Validation : Loss - 3.9468, Accuracy - 50.6276%, Time: 16.3412s
# Epoch-4 learning rate: 1e-05
# Epoch: 6/100
# Epoch : 006, Training: Loss - 1.8745, Accuracy - 79.2128%, Validation : Loss - 3.0468, Accuracy - 58.9958%, Time: 16.4566s
# Epoch-5 learning rate: 1e-05
# Epoch: 7/100
# Epoch : 007, Training: Loss - 1.2877, Accuracy - 86.3469%, Validation : Loss - 2.6652, Accuracy - 65.2720%, Time: 16.4668s
# Epoch-6 learning rate: 1e-05
# Epoch: 8/100
# Epoch : 008, Training: Loss - 1.3132, Accuracy - 84.9938%, Validation : Loss - 2.2161, Accuracy - 70.2929%, Time: 16.4844s
# Epoch-7 learning rate: 1e-05
# Epoch: 9/100
# Epoch : 009, Training: Loss - 0.9422, Accuracy - 89.1759%, Validation : Loss - 1.9783, Accuracy - 73.6402%, Time: 16.4046s
# Epoch-8 learning rate: 1e-05
# Epoch: 10/100
# Epoch : 010, Training: Loss - 0.8496, Accuracy - 90.0369%, Validation : Loss - 1.6197, Accuracy - 76.1506%, Time: 16.4404s
# Epoch-9 learning rate: 1e-05
# Epoch: 11/100
# Epoch : 011, Training: Loss - 0.7616, Accuracy - 91.0209%, Validation : Loss - 1.7040, Accuracy - 75.3138%, Time: 16.4608s
# Epoch-10 learning rate: 1e-05
# Epoch: 12/100
# Epoch : 012, Training: Loss - 0.7833, Accuracy - 90.7749%, Validation : Loss - 1.4107, Accuracy - 79.4979%, Time: 16.8545s
# Epoch-11 learning rate: 1e-05
# Epoch: 13/100
# Epoch : 013, Training: Loss - 0.4682, Accuracy - 93.4809%, Validation : Loss - 1.5029, Accuracy - 76.5690%, Time: 16.5522s
# Epoch-12 learning rate: 1e-05
# Epoch: 14/100
# Epoch : 014, Training: Loss - 0.4962, Accuracy - 93.1119%, Validation : Loss - 1.4679, Accuracy - 76.9874%, Time: 16.5693s
# Epoch-13 learning rate: 1e-05
# Epoch: 15/100
# Epoch : 015, Training: Loss - 0.4086, Accuracy - 93.9729%, Validation : Loss - 1.2783, Accuracy - 79.4979%, Time: 16.4045s
# Epoch-14 learning rate: 1e-05
# Epoch: 16/100
# Epoch : 016, Training: Loss - 0.4253, Accuracy - 93.4809%, Validation : Loss - 1.1560, Accuracy - 81.1715%, Time: 16.4748s
# Epoch-15 learning rate: 1e-05
# Epoch: 17/100
# Epoch : 017, Training: Loss - 0.4602, Accuracy - 92.6199%, Validation : Loss - 1.1162, Accuracy - 81.1715%, Time: 16.4115s
# Epoch-16 learning rate: 1e-05
# Epoch: 18/100
# Epoch : 018, Training: Loss - 0.3563, Accuracy - 93.1119%, Validation : Loss - 0.9889, Accuracy - 83.2636%, Time: 16.5730s
# Epoch-17 learning rate: 1e-05
# Epoch: 19/100
# Epoch : 019, Training: Loss - 0.3993, Accuracy - 93.3579%, Validation : Loss - 0.9332, Accuracy - 82.8452%, Time: 16.3568s
# Epoch-18 learning rate: 1e-05
# Epoch: 20/100
# Epoch : 020, Training: Loss - 0.2756, Accuracy - 94.4649%, Validation : Loss - 0.8522, Accuracy - 83.6820%, Time: 16.4962s
# Epoch-19 learning rate: 1e-05
# Epoch: 21/100
# Epoch : 021, Training: Loss - 0.2404, Accuracy - 94.4649%, Validation : Loss - 0.8315, Accuracy - 83.6820%, Time: 16.3710s
# Epoch-20 learning rate: 1e-05
# Epoch: 22/100
# Epoch : 022, Training: Loss - 0.2182, Accuracy - 95.0800%, Validation : Loss - 0.7800, Accuracy - 84.1004%, Time: 16.5737s
# Epoch-21 learning rate: 1e-05
# Epoch: 23/100
# Epoch : 023, Training: Loss - 0.2554, Accuracy - 95.2030%, Validation : Loss - 0.8559, Accuracy - 83.6820%, Time: 16.3534s
# Epoch-22 learning rate: 1e-05
# Epoch: 24/100
# Epoch : 024, Training: Loss - 0.2255, Accuracy - 96.1870%, Validation : Loss - 0.8494, Accuracy - 82.8452%, Time: 16.4196s
# Epoch-23 learning rate: 1e-05
# Epoch: 25/100
# Epoch : 025, Training: Loss - 0.1923, Accuracy - 96.1870%, Validation : Loss - 0.7432, Accuracy - 84.1004%, Time: 16.5360s
# Epoch-24 learning rate: 1e-05
# Epoch: 26/100
# Epoch : 026, Training: Loss - 0.1850, Accuracy - 95.2030%, Validation : Loss - 0.7139, Accuracy - 84.9372%, Time: 16.6681s
# Epoch-25 learning rate: 1e-05
# Epoch: 27/100
# Epoch : 027, Training: Loss - 0.1300, Accuracy - 96.6790%, Validation : Loss - 0.6749, Accuracy - 84.1004%, Time: 16.5088s
# Epoch-26 learning rate: 1e-05
# Epoch: 28/100
# Epoch : 028, Training: Loss - 0.1893, Accuracy - 96.3100%, Validation : Loss - 0.6885, Accuracy - 84.9372%, Time: 16.6460s
# Epoch-27 learning rate: 1e-05
# Epoch: 29/100
# Epoch : 029, Training: Loss - 0.1321, Accuracy - 96.4330%, Validation : Loss - 0.6764, Accuracy - 84.9372%, Time: 16.7056s
# Epoch-28 learning rate: 1e-05
# Epoch: 30/100
# Epoch : 030, Training: Loss - 0.2176, Accuracy - 94.8339%, Validation : Loss - 0.7080, Accuracy - 83.2636%, Time: 16.8490s
# Epoch-29 learning rate: 1e-05
# Epoch: 31/100
# Epoch : 031, Training: Loss - 0.1257, Accuracy - 96.6790%, Validation : Loss - 0.7339, Accuracy - 83.2636%, Time: 16.8202s
# Epoch-30 learning rate: 1e-05
# Epoch: 32/100
# Epoch : 032, Training: Loss - 0.1291, Accuracy - 96.6790%, Validation : Loss - 0.8746, Accuracy - 82.8452%, Time: 16.6585s
# Epoch-31 learning rate: 1e-05
# Epoch: 33/100
# Epoch : 033, Training: Loss - 0.1808, Accuracy - 95.4490%, Validation : Loss - 0.6666, Accuracy - 84.5188%, Time: 16.6050s
# Epoch-32 learning rate: 1e-05
# Epoch: 34/100
# Epoch : 034, Training: Loss - 0.1685, Accuracy - 95.9410%, Validation : Loss - 0.6608, Accuracy - 83.2636%, Time: 16.8301s
# Epoch-33 learning rate: 1e-05
# Epoch: 35/100
# Epoch : 035, Training: Loss - 0.1379, Accuracy - 96.9250%, Validation : Loss - 0.6846, Accuracy - 82.8452%, Time: 16.6942s
# Epoch-34 learning rate: 1e-05
# Epoch: 36/100
# Epoch : 036, Training: Loss - 0.2044, Accuracy - 94.7109%, Validation : Loss - 0.7029, Accuracy - 83.2636%, Time: 16.9400s
# Epoch-35 learning rate: 1e-05
# Epoch: 37/100
# Epoch : 037, Training: Loss - 0.1583, Accuracy - 95.8180%, Validation : Loss - 0.5153, Accuracy - 87.8661%, Time: 16.8397s
# Epoch-36 learning rate: 1e-05
# Epoch: 38/100
# Epoch : 038, Training: Loss - 0.0957, Accuracy - 97.6630%, Validation : Loss - 0.5386, Accuracy - 86.1925%, Time: 16.9061s
# Epoch-37 learning rate: 1e-05
# Epoch: 39/100
# Epoch : 039, Training: Loss - 0.0874, Accuracy - 97.4170%, Validation : Loss - 0.5708, Accuracy - 84.1004%, Time: 16.7633s
# Epoch-38 learning rate: 1e-05
# Epoch: 40/100
# Epoch : 040, Training: Loss - 0.1149, Accuracy - 96.8020%, Validation : Loss - 0.5979, Accuracy - 83.6820%, Time: 16.9484s
# Epoch-39 learning rate: 1e-05
# Epoch: 41/100
# Epoch : 041, Training: Loss - 0.0795, Accuracy - 97.5400%, Validation : Loss - 0.6534, Accuracy - 82.0084%, Time: 16.8190s
# Epoch-40 learning rate: 1e-05
# Epoch: 42/100
# Epoch : 042, Training: Loss - 0.1060, Accuracy - 97.2940%, Validation : Loss - 0.5140, Accuracy - 85.3556%, Time: 16.7801s
# Epoch-41 learning rate: 1e-05
# Epoch: 43/100
# Epoch : 043, Training: Loss - 0.1149, Accuracy - 96.5560%, Validation : Loss - 0.5165, Accuracy - 84.9372%, Time: 16.6043s
# Epoch-42 learning rate: 1e-05
# Epoch: 44/100
# Epoch : 044, Training: Loss - 0.1381, Accuracy - 96.5560%, Validation : Loss - 0.4908, Accuracy - 85.7741%, Time: 16.6652s
# Epoch-43 learning rate: 1e-05
# Epoch: 45/100
# Epoch : 045, Training: Loss - 0.0962, Accuracy - 97.0480%, Validation : Loss - 0.5399, Accuracy - 85.3556%, Time: 16.3836s
# Epoch-44 learning rate: 1e-05
# Epoch: 46/100
# Epoch : 046, Training: Loss - 0.0706, Accuracy - 97.4170%, Validation : Loss - 0.5815, Accuracy - 84.9372%, Time: 16.4676s
# Epoch-45 learning rate: 1e-05
# Epoch: 47/100
# Epoch : 047, Training: Loss - 0.0571, Accuracy - 98.1550%, Validation : Loss - 0.5774, Accuracy - 84.5188%, Time: 16.5143s
# Epoch-46 learning rate: 1e-05
# Epoch: 48/100
# Epoch : 048, Training: Loss - 0.0505, Accuracy - 98.7700%, Validation : Loss - 0.5095, Accuracy - 87.4477%, Time: 16.6616s
# Epoch-47 learning rate: 1e-05
# Epoch: 49/100
# Epoch : 049, Training: Loss - 0.0603, Accuracy - 97.9090%, Validation : Loss - 0.4624, Accuracy - 87.8661%, Time: 16.6584s
# Epoch-48 learning rate: 1e-05
# Epoch: 50/100
# Epoch : 050, Training: Loss - 0.0697, Accuracy - 98.1550%, Validation : Loss - 0.6130, Accuracy - 84.5188%, Time: 16.8310s
# Epoch-49 learning rate: 1e-05
# Epoch: 51/100
# Epoch : 051, Training: Loss - 0.0610, Accuracy - 97.9090%, Validation : Loss - 0.5314, Accuracy - 86.6109%, Time: 16.9244s
# Epoch-50 learning rate: 1e-05
# Epoch: 52/100
# Epoch : 052, Training: Loss - 0.0675, Accuracy - 97.7860%, Validation : Loss - 0.5868, Accuracy - 82.8452%, Time: 16.8280s
# Epoch-51 learning rate: 1e-05
# Epoch: 53/100
# Epoch : 053, Training: Loss - 0.0835, Accuracy - 97.6630%, Validation : Loss - 0.5483, Accuracy - 87.0293%, Time: 16.6655s
# Epoch-52 learning rate: 1e-05
# Epoch: 54/100
# Epoch : 054, Training: Loss - 0.0648, Accuracy - 97.9090%, Validation : Loss - 0.5492, Accuracy - 87.4477%, Time: 16.7220s
# Epoch-53 learning rate: 1e-05
# Epoch: 55/100
# Epoch : 055, Training: Loss - 0.0440, Accuracy - 98.7700%, Validation : Loss - 0.5862, Accuracy - 84.5188%, Time: 16.7921s
# Epoch-54 learning rate: 1e-05
# Epoch: 56/100
# Epoch : 056, Training: Loss - 0.0349, Accuracy - 99.0160%, Validation : Loss - 0.5284, Accuracy - 88.7029%, Time: 16.6713s
# Epoch-55 learning rate: 1e-05
# Epoch: 57/100
# Epoch : 057, Training: Loss - 0.0262, Accuracy - 98.7700%, Validation : Loss - 0.6540, Accuracy - 81.5900%, Time: 16.6378s
# Epoch-56 learning rate: 1e-05
# Epoch: 58/100
# Epoch : 058, Training: Loss - 0.0604, Accuracy - 98.0320%, Validation : Loss - 0.4706, Accuracy - 87.0293%, Time: 16.8038s
# Epoch-57 learning rate: 1e-05
# Epoch: 59/100
# Epoch : 059, Training: Loss - 0.0407, Accuracy - 98.1550%, Validation : Loss - 0.5523, Accuracy - 83.2636%, Time: 16.5737s
# Epoch-58 learning rate: 1e-05
# Epoch: 60/100
# Epoch : 060, Training: Loss - 0.0401, Accuracy - 98.7700%, Validation : Loss - 0.5194, Accuracy - 87.4477%, Time: 16.5673s
# Epoch-59 learning rate: 1e-05
# Epoch: 61/100
# Epoch : 061, Training: Loss - 0.0549, Accuracy - 97.6630%, Validation : Loss - 0.6344, Accuracy - 84.1004%, Time: 16.6058s
# Epoch-60 learning rate: 1e-05
# Epoch: 62/100
# Epoch : 062, Training: Loss - 0.0491, Accuracy - 98.4010%, Validation : Loss - 0.5117, Accuracy - 84.9372%, Time: 16.7646s
# Epoch-61 learning rate: 9.5e-06
# Epoch: 63/100
# Epoch : 063, Training: Loss - 0.0453, Accuracy - 98.7700%, Validation : Loss - 0.4538, Accuracy - 88.7029%, Time: 16.7930s
# Epoch-62 learning rate: 9.5e-06
# Epoch: 64/100
# Epoch : 064, Training: Loss - 0.0217, Accuracy - 99.5080%, Validation : Loss - 0.4621, Accuracy - 86.1925%, Time: 17.0381s
# Epoch-63 learning rate: 9.5e-06
# Epoch: 65/100
# Epoch : 065, Training: Loss - 0.0257, Accuracy - 99.0160%, Validation : Loss - 0.4632, Accuracy - 86.1925%, Time: 16.6349s
# Epoch-64 learning rate: 9.5e-06
# Epoch: 66/100
# Epoch : 066, Training: Loss - 0.0679, Accuracy - 97.9090%, Validation : Loss - 0.5273, Accuracy - 85.7741%, Time: 16.7313s
# Epoch-65 learning rate: 9.5e-06
# Epoch: 67/100
# Epoch : 067, Training: Loss - 0.0350, Accuracy - 98.8930%, Validation : Loss - 0.4999, Accuracy - 85.7741%, Time: 16.6398s
# Epoch-66 learning rate: 9.025e-06
# Epoch: 68/100
# Epoch : 068, Training: Loss - 0.0521, Accuracy - 97.7860%, Validation : Loss - 0.5573, Accuracy - 84.5188%, Time: 16.8629s
# Epoch-67 learning rate: 9.025e-06
# Epoch: 69/100
# Epoch : 069, Training: Loss - 0.0962, Accuracy - 97.0480%, Validation : Loss - 0.5824, Accuracy - 84.9372%, Time: 16.7085s
# Epoch-68 learning rate: 9.025e-06
# Epoch: 70/100
# Epoch : 070, Training: Loss - 0.0347, Accuracy - 98.7700%, Validation : Loss - 0.5586, Accuracy - 85.7741%, Time: 16.6858s
# Epoch-69 learning rate: 9.025e-06
# Epoch: 71/100
# Epoch : 071, Training: Loss - 0.0349, Accuracy - 98.6470%, Validation : Loss - 0.5607, Accuracy - 84.1004%, Time: 16.6192s
# Epoch-70 learning rate: 8.57375e-06
# Epoch: 72/100
# Epoch : 072, Training: Loss - 0.0445, Accuracy - 98.1550%, Validation : Loss - 0.5658, Accuracy - 84.9372%, Time: 16.6433s
# Epoch-71 learning rate: 8.57375e-06
# Epoch: 73/100
# Epoch : 073, Training: Loss - 0.0418, Accuracy - 98.7700%, Validation : Loss - 0.4061, Accuracy - 87.8661%, Time: 16.5724s
# Epoch-72 learning rate: 8.57375e-06
# Epoch: 74/100
# Epoch : 074, Training: Loss - 0.0457, Accuracy - 98.5240%, Validation : Loss - 0.4049, Accuracy - 87.0293%, Time: 16.6159s
# Epoch-73 learning rate: 8.57375e-06
# Epoch: 75/100
# Epoch : 075, Training: Loss - 0.0233, Accuracy - 99.3850%, Validation : Loss - 0.4522, Accuracy - 85.3556%, Time: 16.5234s
# Epoch-74 learning rate: 8.57375e-06
# Epoch: 76/100
# Epoch : 076, Training: Loss - 0.0266, Accuracy - 99.2620%, Validation : Loss - 0.5029, Accuracy - 85.7741%, Time: 16.5518s
# Epoch-75 learning rate: 8.57375e-06
# Epoch: 77/100
# Epoch : 077, Training: Loss - 0.0287, Accuracy - 98.8930%, Validation : Loss - 0.4863, Accuracy - 85.7741%, Time: 16.3083s
# Epoch-76 learning rate: 8.57375e-06
# Epoch: 78/100
# Epoch : 078, Training: Loss - 0.0221, Accuracy - 99.2620%, Validation : Loss - 0.4635, Accuracy - 86.1925%, Time: 16.2652s
# Epoch-77 learning rate: 8.1450625e-06
# Epoch: 79/100
# Epoch : 079, Training: Loss - 0.0197, Accuracy - 99.2620%, Validation : Loss - 0.4349, Accuracy - 86.6109%, Time: 16.4074s
# Epoch-78 learning rate: 8.1450625e-06
# Epoch: 80/100
# Epoch : 080, Training: Loss - 0.0307, Accuracy - 99.0160%, Validation : Loss - 0.4994, Accuracy - 85.7741%, Time: 16.3921s
# Epoch-79 learning rate: 8.1450625e-06
# Epoch: 81/100
# Epoch : 081, Training: Loss - 0.0230, Accuracy - 99.2620%, Validation : Loss - 0.5870, Accuracy - 84.1004%, Time: 16.2813s
# Epoch-80 learning rate: 8.1450625e-06
# Epoch: 82/100
# Epoch : 082, Training: Loss - 0.0366, Accuracy - 98.6470%, Validation : Loss - 0.5626, Accuracy - 84.1004%, Time: 16.3201s
# Epoch-81 learning rate: 7.737809375e-06
# Epoch: 83/100
# Epoch : 083, Training: Loss - 0.0203, Accuracy - 99.5080%, Validation : Loss - 0.5618, Accuracy - 82.8452%, Time: 16.2428s
# Epoch-82 learning rate: 7.737809375e-06
# Epoch: 84/100
# Epoch : 084, Training: Loss - 0.0254, Accuracy - 99.2620%, Validation : Loss - 0.4539, Accuracy - 85.7741%, Time: 16.4827s
# Epoch-83 learning rate: 7.737809375e-06
# Epoch: 85/100
# Epoch : 085, Training: Loss - 0.0232, Accuracy - 99.2620%, Validation : Loss - 0.5335, Accuracy - 83.6820%, Time: 16.3551s
# Epoch-84 learning rate: 7.737809375e-06
# Epoch: 86/100
# Epoch : 086, Training: Loss - 0.0126, Accuracy - 99.6310%, Validation : Loss - 0.5029, Accuracy - 84.1004%, Time: 16.3529s
# Epoch-85 learning rate: 7.35091890625e-06
# Epoch: 87/100
# Epoch : 087, Training: Loss - 0.0609, Accuracy - 98.5240%, Validation : Loss - 0.4866, Accuracy - 83.6820%, Time: 16.5757s
# Epoch-86 learning rate: 7.35091890625e-06
# Epoch: 88/100
# Epoch : 088, Training: Loss - 0.0224, Accuracy - 99.3850%, Validation : Loss - 0.5553, Accuracy - 84.1004%, Time: 16.4632s
# Epoch-87 learning rate: 7.35091890625e-06
# Epoch: 89/100
# Epoch : 089, Training: Loss - 0.0325, Accuracy - 99.1390%, Validation : Loss - 0.4802, Accuracy - 85.7741%, Time: 16.3168s
# Epoch-88 learning rate: 7.35091890625e-06
# Epoch: 90/100
# Epoch : 090, Training: Loss - 0.0248, Accuracy - 99.2620%, Validation : Loss - 0.4326, Accuracy - 86.1925%, Time: 16.2030s
# Epoch-89 learning rate: 6.9833729609374995e-06
# Epoch: 91/100
# Epoch : 091, Training: Loss - 0.0134, Accuracy - 99.6310%, Validation : Loss - 0.4344, Accuracy - 87.8661%, Time: 16.2392s
# Epoch-90 learning rate: 6.9833729609374995e-06
# Epoch: 92/100
# Epoch : 092, Training: Loss - 0.0311, Accuracy - 99.1390%, Validation : Loss - 0.4327, Accuracy - 86.6109%, Time: 16.4148s
# Epoch-91 learning rate: 6.9833729609374995e-06
# Epoch: 93/100
# Epoch : 093, Training: Loss - 0.0187, Accuracy - 99.3850%, Validation : Loss - 0.5078, Accuracy - 86.1925%, Time: 16.1736s
# Epoch-92 learning rate: 6.9833729609374995e-06
# Epoch: 94/100
# Epoch : 094, Training: Loss - 0.0218, Accuracy - 99.6310%, Validation : Loss - 0.5187, Accuracy - 86.1925%, Time: 16.3692s
# Epoch-93 learning rate: 6.634204312890624e-06
# Epoch: 95/100
# Epoch : 095, Training: Loss - 0.0181, Accuracy - 99.5080%, Validation : Loss - 0.5328, Accuracy - 86.1925%, Time: 16.2798s
# Epoch-94 learning rate: 6.634204312890624e-06
# Epoch: 96/100
# Epoch : 096, Training: Loss - 0.0197, Accuracy - 99.0160%, Validation : Loss - 0.4728, Accuracy - 86.6109%, Time: 16.0592s
# Epoch-95 learning rate: 6.634204312890624e-06
# Epoch: 97/100
# Epoch : 097, Training: Loss - 0.0138, Accuracy - 99.5080%, Validation : Loss - 0.5060, Accuracy - 86.6109%, Time: 16.2539s
# Epoch-96 learning rate: 6.634204312890624e-06
# Epoch: 98/100
# Epoch : 098, Training: Loss - 0.0339, Accuracy - 99.1390%, Validation : Loss - 0.6318, Accuracy - 85.7741%, Time: 16.2903s
# Epoch-97 learning rate: 6.302494097246093e-06
# Epoch: 99/100
# Epoch : 099, Training: Loss - 0.0278, Accuracy - 99.0160%, Validation : Loss - 0.5554, Accuracy - 86.1925%, Time: 16.0592s
# Epoch-98 learning rate: 6.302494097246093e-06
# Epoch: 100/100
# Epoch : 100, Training: Loss - 0.0351, Accuracy - 98.6470%, Validation : Loss - 0.5880, Accuracy - 84.9372%, Time: 16.0955s
# Epoch-99 learning rate: 6.302494097246093e-06

# %%
print("Thoi gian training: ",end-start)
# Out:
# Thoi gian training:  1869.1404542922974

# %%
#save model
import time
from datetime import date
today = date.today()
d1 = today.strftime("%d%m%Y")
print("d1 =", d1)
torch.save(trained_model, '/content/drive/My Drive/DetectBrainTumor/model/pytorch_data_old/model_mobilenet_v3_'+str(d1)+'.pt')
# Out:
# d1 = 04072021

# %%
import pickle
with open('/content/drive/My Drive/DetectBrainTumor/result/pytorch_data_old/history_mobilenet_v3.pickle', 'wb') as f:
    pickle.dump(history, f)

# with open('/content/drive/My Drive/DetectBrainTumor/result/pytorch/time_inceptionresnetv2.pickle', 'wb') as f:
#     pickle.dump(arr_time, f)

# %%
loss_train = []
loss_val = []
acc_train = []
acc_val = []

for i in range(len(history)):
  loss_train.append(history[i][0])
  loss_val.append(history[i][1])
  acc_train.append(history[i][2])
  acc_val.append(history[i][3])

# %%
# summarize history for accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(acc_train)
a[0].plot(acc_val)
a[0].set_title('model accuracy')
a[0].set_ylabel('accuracy')
a[0].set_xlabel('epoch')
a[0].legend(['train', 'val'], loc='upper left')
# summarize history for loss for epoch
# plt.figure(figsize=(10,10))
a[1].plot(loss_train)
a[1].plot(loss_val)
a[1].set_title('model loss')
a[1].set_ylabel('loss')
a[1].set_xlabel('epoch')
a[1].legend(['train', 'val'], loc='upper left')
plt.show()
