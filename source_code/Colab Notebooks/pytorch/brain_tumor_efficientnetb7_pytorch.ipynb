# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Adas/src
from adas import Adas
# Out:
# /content/drive/My Drive/Adas/src

# %%
# !pip install pretrainedmodels
# !pip install albumentations
# !pip install --upgrade efficientnet-pytorch

# %%
import matplotlib.pyplot as plt
from torchvision import datasets, models, transforms
import helper
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
import torch, torchvision
from torch.utils.data import DataLoader
import time
from torchsummary import summary
import numpy as np
import os

from PIL import Image

# %%
IMAGE_SIZE = 256
batch_size = 16

DATADIR_TRAIN = "/content/drive/My Drive/DetectBrainTumor/data_15062021/T2_Train/"
DATADIR_VAL = "/content/drive/My Drive/DetectBrainTumor/data_15062021/T2_Val/"

# %%
# Applying Transforms to the Data
train_transform = transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

test_transform = transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

# %%
train_data = datasets.ImageFolder(DATADIR_TRAIN, transform=train_transform)                                       
val_data = datasets.ImageFolder(DATADIR_VAL, transform=test_transform)

#Data Loading
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True)

# %%
classes = ('YES', 'NO')

# %%
train_data_size = len(train_data)
test_data_size = len(val_data)

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # functions to show an image


# def imshow(img):
#     img = img / 2 + 0.5     # unnormalize
#     npimg = img.numpy()
#     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#     plt.show()


# # get some random training images
# dataiter = iter(train_loader)
# images, labels = dataiter.next()

# # show images
# imshow(torchvision.utils.make_grid(images))
# # print labels
# print(' '.join('%5s' % classes[labels[j]] for j in range(2)))

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
from efficientnet_pytorch import EfficientNet
# model_class = efficientnet_b7(pretrained=True)
model_name = 'efficientnet-b7'
model_class = EfficientNet.from_pretrained(model_name, num_classes=2)
# Out:
# Loaded pretrained weights for efficientnet-b7

# %%
# Freeze model parameters
# for param in model_class.parameters():
#     param.requires_grad = False

# %%
print(model_class)
# Out:
# EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 64, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   )
#   (_bn0): BatchNorm2d(64, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         64, 64, kernel_size=(3, 3), stride=[1, 1], groups=64, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(64, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         64, 16, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         16, 64, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=[2, 2], groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(5, 5), stride=[2, 2], groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (16): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (17): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (18): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(3, 3), stride=[2, 2], groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (19): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (20): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (21): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (22): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (23): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (24): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (25): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (26): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (27): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (28): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=[1, 1], groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (29): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (30): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (31): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (32): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (33): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (34): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (35): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (36): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (37): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (38): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=[2, 2], groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (39): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (40): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
# ...
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (43): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (44): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (45): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (46): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (47): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (48): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (49): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (50): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (51): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(3, 3), stride=[1, 1], groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 640, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (52): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         3840, 3840, kernel_size=(3, 3), stride=(1, 1), groups=3840, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         3840, 160, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         160, 3840, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (53): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         3840, 3840, kernel_size=(3, 3), stride=(1, 1), groups=3840, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         3840, 160, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         160, 3840, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (54): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         3840, 3840, kernel_size=(3, 3), stride=(1, 1), groups=3840, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         3840, 160, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         160, 3840, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     640, 2560, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): BatchNorm2d(2560, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#   (_dropout): Dropout(p=0.5, inplace=False)
#   (_fc): Linear(in_features=2560, out_features=2, bias=True)
#   (_swish): MemoryEfficientSwish()
# )

# %%
# Change the final layer of ResNet50 Model for Transfer Learning
fc_inputs = model_class._fc.in_features

model_class._fc = nn.Sequential(
    nn.Linear(fc_inputs, 128),
    nn.ReLU(),
    nn.Dropout(0.3),
    nn.Flatten(),
    nn.Dropout(0.5),
    nn.Linear(128, 2), # Since 100 possible outputs
    nn.LogSoftmax(dim=1) # For using NLLLoss()
)

# Convert model to be used on GPU
model_class = model_class.to(device)

# %%
def train_and_validate(model, scheduler, loss_criterion, optimizer, epochs):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_loss = 100000.0
    best_epoch = None

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(train_loader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

        scheduler.step()
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(val_loader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)
                if not j%100:
                  print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
        if valid_loss < best_loss:
            best_loss = valid_loss
            best_epoch = epoch

        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_valid_loss = valid_loss/test_data_size 
        avg_valid_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss - {:.4f}, Accuracy - {:.4f}%, Validation : Loss - {:.4f}, Accuracy - {:.4f}%, Time: {:.4f}s".format(epoch+1, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        # torch.save(model, 'model_'+str(epoch)+'.pt')
        # optimizer.epoch_step(epoch)       
    return model, history, best_epoch

# %%
# Define Optimizer and Loss Function
# loss_func = nn.NLLLoss()
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(params=list(model_class.parameters()), lr=2e-5)

# %%
num_epochs = 100

start = time.time()

# trained_model, history, best_epoch = train_and_validate(model_class, loss_func, optimizer, num_epochs)

# scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20,35], gamma=0.1)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

trained_model, history, best_epoch = train_and_validate(model_class, scheduler, loss_func, optimizer, num_epochs)

end = time.time()
# torch.save(history, 'history.pt')
# Out:
# Epoch: 1/100
# Validation Batch number: 000, Validation: Loss: 0.7217, Accuracy: 0.3125
# Epoch : 001, Training: Loss - 0.6869, Accuracy - 54.2435%, Validation : Loss - 0.6948, Accuracy - 49.7908%, Time: 51.4357s
# Epoch: 2/100
# Validation Batch number: 000, Validation: Loss: 0.7039, Accuracy: 0.4375
# Epoch : 002, Training: Loss - 0.6609, Accuracy - 65.5597%, Validation : Loss - 0.6814, Accuracy - 51.8828%, Time: 51.2856s
# Epoch: 3/100
# Validation Batch number: 000, Validation: Loss: 0.6953, Accuracy: 0.5000
# Epoch : 003, Training: Loss - 0.6250, Accuracy - 74.0467%, Validation : Loss - 0.6649, Accuracy - 57.3222%, Time: 51.4792s
# Epoch: 4/100
# Validation Batch number: 000, Validation: Loss: 0.5893, Accuracy: 0.8125
# Epoch : 004, Training: Loss - 0.5492, Accuracy - 83.5178%, Validation : Loss - 0.6439, Accuracy - 64.0167%, Time: 51.2855s
# Epoch: 5/100
# Validation Batch number: 000, Validation: Loss: 0.7449, Accuracy: 0.5000
# Epoch : 005, Training: Loss - 0.4193, Accuracy - 88.8069%, Validation : Loss - 0.6086, Accuracy - 71.1297%, Time: 51.3783s
# Epoch: 6/100
# Validation Batch number: 000, Validation: Loss: 0.7709, Accuracy: 0.6875
# Epoch : 006, Training: Loss - 0.3116, Accuracy - 91.7589%, Validation : Loss - 0.5751, Accuracy - 74.0586%, Time: 51.3876s
# Epoch: 7/100
# Validation Batch number: 000, Validation: Loss: 0.2493, Accuracy: 1.0000
# Epoch : 007, Training: Loss - 0.2322, Accuracy - 93.4809%, Validation : Loss - 0.5297, Accuracy - 78.2427%, Time: 51.2801s
# Epoch: 8/100
# Validation Batch number: 000, Validation: Loss: 0.5341, Accuracy: 0.7500
# Epoch : 008, Training: Loss - 0.1767, Accuracy - 94.4649%, Validation : Loss - 0.5326, Accuracy - 78.2427%, Time: 51.3582s
# Epoch: 9/100
# Validation Batch number: 000, Validation: Loss: 0.3338, Accuracy: 0.9375
# Epoch : 009, Training: Loss - 0.1493, Accuracy - 95.9410%, Validation : Loss - 0.5091, Accuracy - 79.9163%, Time: 51.2835s
# Epoch: 10/100
# Validation Batch number: 000, Validation: Loss: 0.4025, Accuracy: 0.8125
# Epoch : 010, Training: Loss - 0.1113, Accuracy - 97.2940%, Validation : Loss - 0.4800, Accuracy - 80.7531%, Time: 51.4009s
# Epoch: 11/100
# Validation Batch number: 000, Validation: Loss: 0.1905, Accuracy: 1.0000
# Epoch : 011, Training: Loss - 0.1056, Accuracy - 96.9250%, Validation : Loss - 0.4553, Accuracy - 82.4268%, Time: 51.3085s
# Epoch: 12/100
# Validation Batch number: 000, Validation: Loss: 0.5818, Accuracy: 0.8125
# Epoch : 012, Training: Loss - 0.0760, Accuracy - 97.6630%, Validation : Loss - 0.4162, Accuracy - 85.3556%, Time: 51.3455s
# Epoch: 13/100
# Validation Batch number: 000, Validation: Loss: 0.1080, Accuracy: 0.9375
# Epoch : 013, Training: Loss - 0.0714, Accuracy - 98.1550%, Validation : Loss - 0.4597, Accuracy - 84.9372%, Time: 51.3541s
# Epoch: 14/100
# Validation Batch number: 000, Validation: Loss: 0.4747, Accuracy: 0.8125
# Epoch : 014, Training: Loss - 0.0696, Accuracy - 98.1550%, Validation : Loss - 0.3628, Accuracy - 87.8661%, Time: 51.3949s
# Epoch: 15/100
# Validation Batch number: 000, Validation: Loss: 0.0327, Accuracy: 1.0000
# Epoch : 015, Training: Loss - 0.0580, Accuracy - 98.5240%, Validation : Loss - 0.2688, Accuracy - 90.7950%, Time: 51.3322s
# Epoch: 16/100
# Validation Batch number: 000, Validation: Loss: 0.6194, Accuracy: 0.8750
# Epoch : 016, Training: Loss - 0.0431, Accuracy - 98.6470%, Validation : Loss - 0.2779, Accuracy - 90.3766%, Time: 51.3646s
# Epoch: 17/100
# Validation Batch number: 000, Validation: Loss: 0.0850, Accuracy: 0.9375
# Epoch : 017, Training: Loss - 0.0365, Accuracy - 99.0160%, Validation : Loss - 0.2481, Accuracy - 92.0502%, Time: 51.3121s
# Epoch: 18/100
# Validation Batch number: 000, Validation: Loss: 0.0607, Accuracy: 1.0000
# Epoch : 018, Training: Loss - 0.0384, Accuracy - 98.5240%, Validation : Loss - 0.2337, Accuracy - 92.8870%, Time: 51.3229s
# Epoch: 19/100
# Validation Batch number: 000, Validation: Loss: 0.5530, Accuracy: 0.8125
# Epoch : 019, Training: Loss - 0.0480, Accuracy - 98.8930%, Validation : Loss - 0.2642, Accuracy - 92.0502%, Time: 51.3789s
# Epoch: 20/100
# Validation Batch number: 000, Validation: Loss: 0.3844, Accuracy: 0.8750
# Epoch : 020, Training: Loss - 0.0226, Accuracy - 99.7540%, Validation : Loss - 0.2642, Accuracy - 92.4686%, Time: 51.3012s
# Epoch: 21/100
# Validation Batch number: 000, Validation: Loss: 0.2164, Accuracy: 0.9375
# Epoch : 021, Training: Loss - 0.0201, Accuracy - 99.7540%, Validation : Loss - 0.2474, Accuracy - 91.6318%, Time: 51.3862s
# Epoch: 22/100
# Validation Batch number: 000, Validation: Loss: 0.3264, Accuracy: 0.9375
# Epoch : 022, Training: Loss - 0.0278, Accuracy - 99.6310%, Validation : Loss - 0.2612, Accuracy - 92.4686%, Time: 51.3127s
# Epoch: 23/100
# Validation Batch number: 000, Validation: Loss: 0.2325, Accuracy: 0.8750
# Epoch : 023, Training: Loss - 0.0229, Accuracy - 99.2620%, Validation : Loss - 0.2590, Accuracy - 92.0502%, Time: 51.3089s
# Epoch: 24/100
# Validation Batch number: 000, Validation: Loss: 0.2343, Accuracy: 0.8750
# Epoch : 024, Training: Loss - 0.0493, Accuracy - 98.5240%, Validation : Loss - 0.2482, Accuracy - 92.0502%, Time: 51.3162s
# Epoch: 25/100
# Validation Batch number: 000, Validation: Loss: 0.7377, Accuracy: 0.7500
# Epoch : 025, Training: Loss - 0.0430, Accuracy - 98.5240%, Validation : Loss - 0.2312, Accuracy - 92.4686%, Time: 51.3144s
# Epoch: 26/100
# Validation Batch number: 000, Validation: Loss: 0.5548, Accuracy: 0.8750
# Epoch : 026, Training: Loss - 0.0152, Accuracy - 99.8770%, Validation : Loss - 0.2284, Accuracy - 92.8870%, Time: 51.3930s
# Epoch: 27/100
# Validation Batch number: 000, Validation: Loss: 0.0872, Accuracy: 0.9375
# Epoch : 027, Training: Loss - 0.0163, Accuracy - 99.6310%, Validation : Loss - 0.2388, Accuracy - 92.8870%, Time: 51.3721s
# Epoch: 28/100
# Validation Batch number: 000, Validation: Loss: 0.0799, Accuracy: 0.9375
# Epoch : 028, Training: Loss - 0.0153, Accuracy - 99.6310%, Validation : Loss - 0.2402, Accuracy - 92.0502%, Time: 51.3235s
# Epoch: 29/100
# Validation Batch number: 000, Validation: Loss: 0.5613, Accuracy: 0.8125
# Epoch : 029, Training: Loss - 0.0148, Accuracy - 99.7540%, Validation : Loss - 0.2371, Accuracy - 91.6318%, Time: 51.3370s
# Epoch: 30/100
# Validation Batch number: 000, Validation: Loss: 0.2371, Accuracy: 0.8750
# Epoch : 030, Training: Loss - 0.0135, Accuracy - 99.7540%, Validation : Loss - 0.2412, Accuracy - 91.6318%, Time: 51.3143s
# Epoch: 31/100
# Validation Batch number: 000, Validation: Loss: 0.2208, Accuracy: 0.8750
# Epoch : 031, Training: Loss - 0.0101, Accuracy - 99.8770%, Validation : Loss - 0.2453, Accuracy - 91.6318%, Time: 51.3169s
# Epoch: 32/100
# Validation Batch number: 000, Validation: Loss: 0.2818, Accuracy: 0.8125
# Epoch : 032, Training: Loss - 0.0120, Accuracy - 99.8770%, Validation : Loss - 0.2532, Accuracy - 91.6318%, Time: 51.3875s
# Epoch: 33/100
# Validation Batch number: 000, Validation: Loss: 0.2676, Accuracy: 0.9375
# Epoch : 033, Training: Loss - 0.0210, Accuracy - 99.5080%, Validation : Loss - 0.2390, Accuracy - 91.6318%, Time: 51.2972s
# Epoch: 34/100
# Validation Batch number: 000, Validation: Loss: 0.0183, Accuracy: 1.0000
# Epoch : 034, Training: Loss - 0.0130, Accuracy - 99.7540%, Validation : Loss - 0.2401, Accuracy - 92.0502%, Time: 51.3242s
# Epoch: 35/100
# Validation Batch number: 000, Validation: Loss: 0.0093, Accuracy: 1.0000
# Epoch : 035, Training: Loss - 0.0146, Accuracy - 99.6310%, Validation : Loss - 0.2331, Accuracy - 91.6318%, Time: 51.2770s
# Epoch: 36/100
# Validation Batch number: 000, Validation: Loss: 0.2399, Accuracy: 0.8750
# Epoch : 036, Training: Loss - 0.0150, Accuracy - 99.6310%, Validation : Loss - 0.2375, Accuracy - 91.6318%, Time: 51.3581s
# Epoch: 37/100
# Validation Batch number: 000, Validation: Loss: 0.0170, Accuracy: 1.0000
# Epoch : 037, Training: Loss - 0.0101, Accuracy - 99.8770%, Validation : Loss - 0.2406, Accuracy - 91.6318%, Time: 51.3406s
# Epoch: 38/100
# Validation Batch number: 000, Validation: Loss: 0.2330, Accuracy: 0.9375
# Epoch : 038, Training: Loss - 0.0079, Accuracy - 99.8770%, Validation : Loss - 0.2455, Accuracy - 92.0502%, Time: 51.3165s
# Epoch: 39/100
# Validation Batch number: 000, Validation: Loss: 0.0015, Accuracy: 1.0000
# Epoch : 039, Training: Loss - 0.0078, Accuracy - 99.8770%, Validation : Loss - 0.2402, Accuracy - 92.0502%, Time: 51.3345s
# Epoch: 40/100
# Validation Batch number: 000, Validation: Loss: 0.1457, Accuracy: 0.9375
# Epoch : 040, Training: Loss - 0.0066, Accuracy - 99.8770%, Validation : Loss - 0.2586, Accuracy - 91.6318%, Time: 51.3602s
# Epoch: 41/100
# Validation Batch number: 000, Validation: Loss: 0.4850, Accuracy: 0.8750
# Epoch : 041, Training: Loss - 0.0079, Accuracy - 99.7540%, Validation : Loss - 0.2506, Accuracy - 92.0502%, Time: 51.2758s
# Epoch: 42/100
# Validation Batch number: 000, Validation: Loss: 0.3188, Accuracy: 0.8750
# Epoch : 042, Training: Loss - 0.0080, Accuracy - 99.8770%, Validation : Loss - 0.2495, Accuracy - 91.6318%, Time: 51.3776s
# Epoch: 43/100
# Validation Batch number: 000, Validation: Loss: 0.0228, Accuracy: 1.0000
# Epoch : 043, Training: Loss - 0.0095, Accuracy - 99.8770%, Validation : Loss - 0.2568, Accuracy - 92.0502%, Time: 51.4280s
# Epoch: 44/100
# Validation Batch number: 000, Validation: Loss: 0.0024, Accuracy: 1.0000
# Epoch : 044, Training: Loss - 0.0107, Accuracy - 99.8770%, Validation : Loss - 0.2577, Accuracy - 92.4686%, Time: 51.3260s
# Epoch: 45/100
# Validation Batch number: 000, Validation: Loss: 0.3296, Accuracy: 0.9375
# Epoch : 045, Training: Loss - 0.0209, Accuracy - 99.5080%, Validation : Loss - 0.2504, Accuracy - 92.4686%, Time: 51.3713s
# Epoch: 46/100
# Validation Batch number: 000, Validation: Loss: 0.3277, Accuracy: 0.9375
# Epoch : 046, Training: Loss - 0.0134, Accuracy - 99.6310%, Validation : Loss - 0.2473, Accuracy - 92.0502%, Time: 51.3549s
# Epoch: 47/100
# Validation Batch number: 000, Validation: Loss: 0.3372, Accuracy: 0.8750
# Epoch : 047, Training: Loss - 0.0175, Accuracy - 99.3850%, Validation : Loss - 0.2433, Accuracy - 92.0502%, Time: 51.1975s
# Epoch: 48/100
# Validation Batch number: 000, Validation: Loss: 0.5457, Accuracy: 0.8125
# Epoch : 048, Training: Loss - 0.0144, Accuracy - 99.7540%, Validation : Loss - 0.2336, Accuracy - 92.0502%, Time: 51.3011s
# Epoch: 49/100
# Validation Batch number: 000, Validation: Loss: 0.3224, Accuracy: 0.9375
# Epoch : 049, Training: Loss - 0.0124, Accuracy - 99.7540%, Validation : Loss - 0.2426, Accuracy - 92.0502%, Time: 51.3546s
# Epoch: 50/100
# Validation Batch number: 000, Validation: Loss: 0.0069, Accuracy: 1.0000
# Epoch : 050, Training: Loss - 0.0088, Accuracy - 99.7540%, Validation : Loss - 0.2413, Accuracy - 91.6318%, Time: 51.2865s
# Epoch: 51/100
# Validation Batch number: 000, Validation: Loss: 0.5303, Accuracy: 0.8750
# Epoch : 051, Training: Loss - 0.0071, Accuracy - 99.8770%, Validation : Loss - 0.2442, Accuracy - 91.6318%, Time: 51.3272s
# Epoch: 52/100
# Validation Batch number: 000, Validation: Loss: 0.0902, Accuracy: 0.9375
# Epoch : 052, Training: Loss - 0.0065, Accuracy - 99.8770%, Validation : Loss - 0.2503, Accuracy - 91.6318%, Time: 51.3859s
# Epoch: 53/100
# Validation Batch number: 000, Validation: Loss: 0.1360, Accuracy: 0.9375
# Epoch : 053, Training: Loss - 0.0053, Accuracy - 100.0000%, Validation : Loss - 0.2501, Accuracy - 91.6318%, Time: 51.2035s
# Epoch: 54/100
# Validation Batch number: 000, Validation: Loss: 0.5192, Accuracy: 0.8750
# Epoch : 054, Training: Loss - 0.0068, Accuracy - 99.8770%, Validation : Loss - 0.2484, Accuracy - 92.0502%, Time: 51.3298s
# Epoch: 55/100
# Validation Batch number: 000, Validation: Loss: 0.2544, Accuracy: 0.9375
# Epoch : 055, Training: Loss - 0.0045, Accuracy - 100.0000%, Validation : Loss - 0.2516, Accuracy - 92.0502%, Time: 51.2624s
# Epoch: 56/100
# Validation Batch number: 000, Validation: Loss: 0.0123, Accuracy: 1.0000
# Epoch : 056, Training: Loss - 0.0060, Accuracy - 99.7540%, Validation : Loss - 0.2519, Accuracy - 92.0502%, Time: 51.3081s
# Epoch: 57/100
# Validation Batch number: 000, Validation: Loss: 0.2276, Accuracy: 0.8750
# Epoch : 057, Training: Loss - 0.0068, Accuracy - 99.8770%, Validation : Loss - 0.2477, Accuracy - 92.4686%, Time: 51.4080s
# Epoch: 58/100
# Validation Batch number: 000, Validation: Loss: 0.0013, Accuracy: 1.0000
# Epoch : 058, Training: Loss - 0.0103, Accuracy - 99.7540%, Validation : Loss - 0.2557, Accuracy - 92.4686%, Time: 51.3488s
# Epoch: 59/100
# Validation Batch number: 000, Validation: Loss: 0.3722, Accuracy: 0.9375
# Epoch : 059, Training: Loss - 0.0070, Accuracy - 99.8770%, Validation : Loss - 0.2661, Accuracy - 92.8870%, Time: 51.3077s
# Epoch: 60/100
# Validation Batch number: 000, Validation: Loss: 0.3578, Accuracy: 0.9375
# Epoch : 060, Training: Loss - 0.0117, Accuracy - 99.7540%, Validation : Loss - 0.2848, Accuracy - 92.4686%, Time: 51.3127s
# Epoch: 61/100
# Validation Batch number: 000, Validation: Loss: 0.1245, Accuracy: 0.9375
# Epoch : 061, Training: Loss - 0.0031, Accuracy - 100.0000%, Validation : Loss - 0.2800, Accuracy - 92.4686%, Time: 51.3478s
# Epoch: 62/100
# Validation Batch number: 000, Validation: Loss: 0.6165, Accuracy: 0.8750
# Epoch : 062, Training: Loss - 0.0043, Accuracy - 100.0000%, Validation : Loss - 0.2747, Accuracy - 92.4686%, Time: 51.2401s
# Epoch: 63/100
# Validation Batch number: 000, Validation: Loss: 0.4471, Accuracy: 0.8750
# Epoch : 063, Training: Loss - 0.0098, Accuracy - 99.7540%, Validation : Loss - 0.2709, Accuracy - 92.4686%, Time: 51.3925s
# Epoch: 64/100
# Validation Batch number: 000, Validation: Loss: 0.0056, Accuracy: 1.0000
# Epoch : 064, Training: Loss - 0.0067, Accuracy - 99.8770%, Validation : Loss - 0.2611, Accuracy - 92.4686%, Time: 51.3328s
# Epoch: 65/100
# Validation Batch number: 000, Validation: Loss: 0.0056, Accuracy: 1.0000
# Epoch : 065, Training: Loss - 0.0052, Accuracy - 99.8770%, Validation : Loss - 0.2654, Accuracy - 92.0502%, Time: 51.2599s
# Epoch: 66/100
# Validation Batch number: 000, Validation: Loss: 0.0591, Accuracy: 1.0000
# Epoch : 066, Training: Loss - 0.0043, Accuracy - 100.0000%, Validation : Loss - 0.2682, Accuracy - 92.0502%, Time: 51.3173s
# Epoch: 67/100
# Validation Batch number: 000, Validation: Loss: 0.1828, Accuracy: 0.9375
# Epoch : 067, Training: Loss - 0.0255, Accuracy - 99.2620%, Validation : Loss - 0.2786, Accuracy - 92.4686%, Time: 51.2738s
# Epoch: 68/100
# Validation Batch number: 000, Validation: Loss: 0.0026, Accuracy: 1.0000
# Epoch : 068, Training: Loss - 0.0043, Accuracy - 99.8770%, Validation : Loss - 0.2797, Accuracy - 92.4686%, Time: 51.2903s
# Epoch: 69/100
# Validation Batch number: 000, Validation: Loss: 0.4446, Accuracy: 0.9375
# Epoch : 069, Training: Loss - 0.0037, Accuracy - 100.0000%, Validation : Loss - 0.2791, Accuracy - 92.4686%, Time: 51.3888s
# Epoch: 70/100
# Validation Batch number: 000, Validation: Loss: 0.9149, Accuracy: 0.8125
# Epoch : 070, Training: Loss - 0.0095, Accuracy - 99.8770%, Validation : Loss - 0.2776, Accuracy - 92.4686%, Time: 51.3715s
# Epoch: 71/100
# Validation Batch number: 000, Validation: Loss: 0.2970, Accuracy: 0.9375
# Epoch : 071, Training: Loss - 0.0052, Accuracy - 99.8770%, Validation : Loss - 0.2767, Accuracy - 92.4686%, Time: 51.2784s
# Epoch: 72/100
# Validation Batch number: 000, Validation: Loss: 0.0026, Accuracy: 1.0000
# Epoch : 072, Training: Loss - 0.0061, Accuracy - 99.8770%, Validation : Loss - 0.2818, Accuracy - 92.4686%, Time: 51.3113s
# Epoch: 73/100
# Validation Batch number: 000, Validation: Loss: 0.2073, Accuracy: 0.9375
# Epoch : 073, Training: Loss - 0.0110, Accuracy - 99.7540%, Validation : Loss - 0.2804, Accuracy - 92.4686%, Time: 51.2921s
# Epoch: 74/100
# Validation Batch number: 000, Validation: Loss: 1.0035, Accuracy: 0.8125
# Epoch : 074, Training: Loss - 0.0055, Accuracy - 99.8770%, Validation : Loss - 0.2817, Accuracy - 92.4686%, Time: 51.2801s
# Epoch: 75/100
# Validation Batch number: 000, Validation: Loss: 0.5043, Accuracy: 0.8750
# Epoch : 075, Training: Loss - 0.0039, Accuracy - 100.0000%, Validation : Loss - 0.2796, Accuracy - 92.4686%, Time: 51.3465s
# Epoch: 76/100
# Validation Batch number: 000, Validation: Loss: 0.0016, Accuracy: 1.0000
# Epoch : 076, Training: Loss - 0.0029, Accuracy - 100.0000%, Validation : Loss - 0.2823, Accuracy - 92.4686%, Time: 51.3382s
# Epoch: 77/100
# Validation Batch number: 000, Validation: Loss: 0.0324, Accuracy: 1.0000
# Epoch : 077, Training: Loss - 0.0071, Accuracy - 99.7540%, Validation : Loss - 0.2804, Accuracy - 92.4686%, Time: 51.2576s
# Epoch: 78/100
# Validation Batch number: 000, Validation: Loss: 0.1821, Accuracy: 0.8750
# Epoch : 078, Training: Loss - 0.0054, Accuracy - 99.8770%, Validation : Loss - 0.2809, Accuracy - 92.4686%, Time: 51.3102s
# Epoch: 79/100
# Validation Batch number: 000, Validation: Loss: 0.0018, Accuracy: 1.0000
# Epoch : 079, Training: Loss - 0.0136, Accuracy - 99.5080%, Validation : Loss - 0.2720, Accuracy - 92.4686%, Time: 51.2855s
# Epoch: 80/100
# Validation Batch number: 000, Validation: Loss: 0.3511, Accuracy: 0.8750
# Epoch : 080, Training: Loss - 0.0027, Accuracy - 100.0000%, Validation : Loss - 0.2731, Accuracy - 92.4686%, Time: 51.2800s
# Epoch: 81/100
# Validation Batch number: 000, Validation: Loss: 0.4041, Accuracy: 0.8750
# Epoch : 081, Training: Loss - 0.0036, Accuracy - 100.0000%, Validation : Loss - 0.2754, Accuracy - 92.4686%, Time: 51.3529s
# Epoch: 82/100
# Validation Batch number: 000, Validation: Loss: 0.0215, Accuracy: 1.0000
# Epoch : 082, Training: Loss - 0.0093, Accuracy - 99.7540%, Validation : Loss - 0.2782, Accuracy - 92.4686%, Time: 51.3515s
# Epoch: 83/100
# Validation Batch number: 000, Validation: Loss: 0.0104, Accuracy: 1.0000
# Epoch : 083, Training: Loss - 0.0118, Accuracy - 99.8770%, Validation : Loss - 0.2803, Accuracy - 92.4686%, Time: 51.2571s
# Epoch: 84/100
# Validation Batch number: 000, Validation: Loss: 0.0613, Accuracy: 1.0000
# Epoch : 084, Training: Loss - 0.0026, Accuracy - 100.0000%, Validation : Loss - 0.2804, Accuracy - 92.4686%, Time: 51.3305s
# Epoch: 85/100
# Validation Batch number: 000, Validation: Loss: 0.2774, Accuracy: 0.9375
# Epoch : 085, Training: Loss - 0.0075, Accuracy - 99.8770%, Validation : Loss - 0.2796, Accuracy - 92.4686%, Time: 51.2660s
# Epoch: 86/100
# Validation Batch number: 000, Validation: Loss: 0.2174, Accuracy: 0.9375
# Epoch : 086, Training: Loss - 0.0100, Accuracy - 99.7540%, Validation : Loss - 0.2795, Accuracy - 92.4686%, Time: 51.3026s
# Epoch: 87/100
# Validation Batch number: 000, Validation: Loss: 0.0081, Accuracy: 1.0000
# Epoch : 087, Training: Loss - 0.0108, Accuracy - 99.8770%, Validation : Loss - 0.2819, Accuracy - 92.4686%, Time: 51.3512s
# Epoch: 88/100
# Validation Batch number: 000, Validation: Loss: 0.1606, Accuracy: 0.9375
# Epoch : 088, Training: Loss - 0.0033, Accuracy - 100.0000%, Validation : Loss - 0.2824, Accuracy - 92.4686%, Time: 51.3166s
# Epoch: 89/100
# Validation Batch number: 000, Validation: Loss: 0.2712, Accuracy: 0.8750
# Epoch : 089, Training: Loss - 0.0045, Accuracy - 99.8770%, Validation : Loss - 0.2846, Accuracy - 92.4686%, Time: 51.2587s
# Epoch: 90/100
# Validation Batch number: 000, Validation: Loss: 0.0301, Accuracy: 1.0000
# Epoch : 090, Training: Loss - 0.0050, Accuracy - 99.8770%, Validation : Loss - 0.2849, Accuracy - 92.4686%, Time: 51.3462s
# Epoch: 91/100
# Validation Batch number: 000, Validation: Loss: 0.1288, Accuracy: 0.9375
# Epoch : 091, Training: Loss - 0.0025, Accuracy - 100.0000%, Validation : Loss - 0.2831, Accuracy - 92.4686%, Time: 51.3192s
# Epoch: 92/100
# Validation Batch number: 000, Validation: Loss: 0.0373, Accuracy: 1.0000
# Epoch : 092, Training: Loss - 0.0052, Accuracy - 99.8770%, Validation : Loss - 0.2854, Accuracy - 92.4686%, Time: 51.3756s
# Epoch: 93/100
# Validation Batch number: 000, Validation: Loss: 0.0103, Accuracy: 1.0000
# Epoch : 093, Training: Loss - 0.0105, Accuracy - 99.6310%, Validation : Loss - 0.2891, Accuracy - 92.4686%, Time: 51.3939s
# Epoch: 94/100
# Validation Batch number: 000, Validation: Loss: 0.2469, Accuracy: 0.8750
# Epoch : 094, Training: Loss - 0.0064, Accuracy - 99.7540%, Validation : Loss - 0.2914, Accuracy - 92.4686%, Time: 51.3062s
# Epoch: 95/100
# Validation Batch number: 000, Validation: Loss: 0.0352, Accuracy: 1.0000
# Epoch : 095, Training: Loss - 0.0030, Accuracy - 100.0000%, Validation : Loss - 0.2920, Accuracy - 92.4686%, Time: 51.2723s
# Epoch: 96/100
# Validation Batch number: 000, Validation: Loss: 1.0133, Accuracy: 0.7500
# Epoch : 096, Training: Loss - 0.0052, Accuracy - 99.8770%, Validation : Loss - 0.2907, Accuracy - 92.0502%, Time: 51.3071s
# Epoch: 97/100
# Validation Batch number: 000, Validation: Loss: 0.3422, Accuracy: 0.9375
# Epoch : 097, Training: Loss - 0.0041, Accuracy - 100.0000%, Validation : Loss - 0.2909, Accuracy - 92.4686%, Time: 51.3542s
# Epoch: 98/100
# Validation Batch number: 000, Validation: Loss: 0.0241, Accuracy: 1.0000
# Epoch : 098, Training: Loss - 0.0034, Accuracy - 100.0000%, Validation : Loss - 0.2927, Accuracy - 92.4686%, Time: 51.3392s
# Epoch: 99/100
# Validation Batch number: 000, Validation: Loss: 0.2313, Accuracy: 0.9375
# Epoch : 099, Training: Loss - 0.0129, Accuracy - 99.6310%, Validation : Loss - 0.2911, Accuracy - 92.4686%, Time: 51.3130s
# Epoch: 100/100
# Validation Batch number: 000, Validation: Loss: 0.1601, Accuracy: 0.9375
# Epoch : 100, Training: Loss - 0.0038, Accuracy - 99.8770%, Validation : Loss - 0.2898, Accuracy - 92.4686%, Time: 51.6431s

# %%
print("Thoi gian training: ",end-start)
# Out:
# Thoi gian training:  5133.116217136383

# %%
#save model
import time
from datetime import date
today = date.today()
d1 = today.strftime("%d%m%Y")
print("d1 =", d1)
torch.save(trained_model, '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_efficientnetb7_'+str(d1)+'.pt')
# Out:
# d1 = 26062021

# %%
import pickle
with open('/content/drive/My Drive/DetectBrainTumor/result/pytorch/history_efficientnetb7.pickle', 'wb') as f:
    pickle.dump(history, f)

# with open('/content/drive/My Drive/DetectBrainTumor/result/pytorch/time_resnet152.pickle', 'wb') as f:
#     pickle.dump(arr_time, f)

# %%
loss_train = []
loss_val = []
acc_train = []
acc_val = []

for i in range(len(history)):
  loss_train.append(history[i][0])
  loss_val.append(history[i][1])
  acc_train.append(history[i][2])
  acc_val.append(history[i][3])

# %%
# summarize history for accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(acc_train)
a[0].plot(acc_val)
a[0].set_title('model accuracy')
a[0].set_ylabel('accuracy')
a[0].set_xlabel('epoch')
a[0].legend(['train', 'val'], loc='upper left')
# summarize history for loss for epoch
# plt.figure(figsize=(10,10))
a[1].plot(loss_train)
a[1].plot(loss_val)
a[1].set_title('model loss')
a[1].set_ylabel('loss')
a[1].set_xlabel('epoch')
a[1].legend(['train', 'val'], loc='upper left')
plt.show()
