# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
#history
data_densenet201 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch/history_denseNet201.pickle"
data_resnet152v2 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch/history_resnet152v2.pickle"
data_mobilenet_v3 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch/history_mobilenet_v3.pickle"
data_vgg19 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch/history_vgg19.pickle"



data_old_densenet201 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch_data_old/history_denseNet201.pickle"
data_old_resnet152v2 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch_data_old/history_resnet152v2.pickle"
data_old_mobilenet_v3 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch_data_old/history_mobilenet_v3.pickle"
data_old_vgg19 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch_data_old/history_vgg19.pickle"

data_adas_densenet201 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch/history_adas_denseNet201.pickle"
data_adas_resnet152v2 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch/history_adas_resnet152v2.pickle"
data_adas_mobilenet_v3 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch/history_adas_mobilenet_v3.pickle"
data_adas_vgg19 = "/content/drive/My Drive/DetectBrainTumor/result/pytorch/history_adas_vgg19.pickle"

# %%
#history
history_densenet201 = pickle.load(open(data_densenet201, 'rb'))
history_resnet152v2 = pickle.load(open(data_resnet152v2, 'rb'))
history_mobilenet_v3 = pickle.load(open(data_mobilenet_v3, 'rb'))
history_vgg19 = pickle.load(open(data_vgg19, 'rb'))

#history_old
history_old_densenet201 = pickle.load(open(data_old_densenet201, 'rb'))
history_old_resnet152v2 = pickle.load(open(data_old_resnet152v2, 'rb'))
history_old_mobilenet_v3 = pickle.load(open(data_old_mobilenet_v3, 'rb'))
history_old_vgg19 = pickle.load(open(data_old_vgg19, 'rb'))

#history_adas
history_adas_densenet201 = pickle.load(open(data_adas_densenet201, 'rb'))
history_adas_resnet152v2 = pickle.load(open(data_adas_resnet152v2, 'rb'))
history_adas_mobilenet_v3 = pickle.load(open(data_adas_mobilenet_v3, 'rb'))
history_adas_vgg19 = pickle.load(open(data_adas_vgg19, 'rb'))

# %%
# %cd "/content/drive/My Drive/DetectBrainTumor/result/new/"
# %ls
# %mv 'history_accuracy_efficientnetb7 (1).pickle' 'history_accuracy_efficientnetb7.pickle'
# %mv 'history_loss_efficientnetb7 (1).pickle' 'history_loss_efficientnetb7.pickle'

# %%
#densenet201
loss_train_densenet201 = []
loss_val_densenet201 = []
acc_train_densenet201 = []
acc_val_densenet201 = []

for i in range(len(history_densenet201)):
  loss_train_densenet201.append(history_densenet201[i][0])
  loss_val_densenet201.append(history_densenet201[i][1])
  acc_train_densenet201.append(history_densenet201[i][2])
  acc_val_densenet201.append(history_densenet201[i][3])

#resnet152v2
loss_train_resnet152v2 = []
loss_val_resnet152v2 = []
acc_train_resnet152v2 = []
acc_val_resnet152v2 = []

for i in range(len(history_resnet152v2)):
  loss_train_resnet152v2.append(history_resnet152v2[i][0])
  loss_val_resnet152v2.append(history_resnet152v2[i][1])
  acc_train_resnet152v2.append(history_resnet152v2[i][2])
  acc_val_resnet152v2.append(history_resnet152v2[i][3])

#mobilenet_v3
loss_train_mobilenet_v3 = []
loss_val_mobilenet_v3 = []
acc_train_mobilenet_v3 = []
acc_val_mobilenet_v3 = []

for i in range(len(history_mobilenet_v3)):
  loss_train_mobilenet_v3.append(history_mobilenet_v3[i][0])
  loss_val_mobilenet_v3.append(history_mobilenet_v3[i][1])
  acc_train_mobilenet_v3.append(history_mobilenet_v3[i][2])
  acc_val_mobilenet_v3.append(history_mobilenet_v3[i][3])

#vgg19
loss_train_vgg19 = []
loss_val_vgg19 = []
acc_train_vgg19 = []
acc_val_vgg19 = []

for i in range(len(history_vgg19)):
  loss_train_vgg19.append(history_vgg19[i][0])
  loss_val_vgg19.append(history_vgg19[i][1])
  acc_train_vgg19.append(history_vgg19[i][2])
  acc_val_vgg19.append(history_vgg19[i][3])


####old
#densenet201
loss_old_train_densenet201 = []
loss_old_val_densenet201 = []
acc_old_train_densenet201 = []
acc_old_val_densenet201 = []

for i in range(len(history_old_densenet201)):
  loss_old_train_densenet201.append(history_old_densenet201[i][0])
  loss_old_val_densenet201.append(history_old_densenet201[i][1])
  acc_old_train_densenet201.append(history_old_densenet201[i][2])
  acc_old_val_densenet201.append(history_old_densenet201[i][3])

#resnet152v2
loss_old_train_resnet152v2 = []
loss_old_val_resnet152v2 = []
acc_old_train_resnet152v2 = []
acc_old_val_resnet152v2 = []

for i in range(len(history_old_resnet152v2)):
  loss_old_train_resnet152v2.append(history_old_resnet152v2[i][0])
  loss_old_val_resnet152v2.append(history_old_resnet152v2[i][1])
  acc_old_train_resnet152v2.append(history_old_resnet152v2[i][2])
  acc_old_val_resnet152v2.append(history_old_resnet152v2[i][3])


#mobilenet_v3
loss_old_train_mobilenet_v3 = []
loss_old_val_mobilenet_v3 = []
acc_old_train_mobilenet_v3 = []
acc_old_val_mobilenet_v3 = []

for i in range(len(history_old_mobilenet_v3)):
  loss_old_train_mobilenet_v3.append(history_old_mobilenet_v3[i][0])
  loss_old_val_mobilenet_v3.append(history_old_mobilenet_v3[i][1])
  acc_old_train_mobilenet_v3.append(history_old_mobilenet_v3[i][2])
  acc_old_val_mobilenet_v3.append(history_old_mobilenet_v3[i][3])

#vgg19
loss_old_train_vgg19 = []
loss_old_val_vgg19 = []
acc_old_train_vgg19 = []
acc_old_val_vgg19 = []

for i in range(len(history_old_vgg19)):
  loss_old_train_vgg19.append(history_old_vgg19[i][0])
  loss_old_val_vgg19.append(history_old_vgg19[i][1])
  acc_old_train_vgg19.append(history_old_vgg19[i][2])
  acc_old_val_vgg19.append(history_old_vgg19[i][3])


#adas
#densenet201
loss_adas_train_densenet201 = []
loss_adas_val_densenet201 = []
acc_adas_train_densenet201 = []
acc_adas_val_densenet201 = []

for i in range(len(history_adas_densenet201)):
  loss_adas_train_densenet201.append(history_adas_densenet201[i][0])
  loss_adas_val_densenet201.append(history_adas_densenet201[i][1])
  acc_adas_train_densenet201.append(history_adas_densenet201[i][2])
  acc_adas_val_densenet201.append(history_adas_densenet201[i][3])

#resnet152v2
loss_adas_train_resnet152v2 = []
loss_adas_val_resnet152v2 = []
acc_adas_train_resnet152v2 = []
acc_adas_val_resnet152v2 = []

for i in range(len(history_adas_resnet152v2)):
  loss_adas_train_resnet152v2.append(history_adas_resnet152v2[i][0])
  loss_adas_val_resnet152v2.append(history_adas_resnet152v2[i][1])
  acc_adas_train_resnet152v2.append(history_adas_resnet152v2[i][2])
  acc_adas_val_resnet152v2.append(history_adas_resnet152v2[i][3])  

#mobilenet_v3
loss_adas_train_mobilenet_v3 = []
loss_adas_val_mobilenet_v3 = []
acc_adas_train_mobilenet_v3 = []
acc_adas_val_mobilenet_v3 = []

for i in range(len(history_adas_mobilenet_v3)):
  loss_adas_train_mobilenet_v3.append(history_adas_mobilenet_v3[i][0])
  loss_adas_val_mobilenet_v3.append(history_adas_mobilenet_v3[i][1])
  acc_adas_train_mobilenet_v3.append(history_adas_mobilenet_v3[i][2])
  acc_adas_val_mobilenet_v3.append(history_adas_mobilenet_v3[i][3])

#vgg19
loss_adas_train_vgg19 = []
loss_adas_val_vgg19 = []
acc_adas_train_vgg19 = []
acc_adas_val_vgg19 = []

for i in range(len(history_adas_vgg19)):
  loss_adas_train_vgg19.append(history_adas_vgg19[i][0])
  loss_adas_val_vgg19.append(history_adas_vgg19[i][1])
  acc_adas_train_vgg19.append(history_adas_vgg19[i][2])
  acc_adas_val_vgg19.append(history_adas_vgg19[i][3])

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(acc_train_densenet201, '-o', markersize=10)
a[0].plot(acc_old_train_densenet201, '-*', markersize=10)
a[0].set_title('Model Train Accuracy DenseNet201', fontsize=18)
a[0].set_ylabel('accuracy', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['densenet201_with_crop', 'densenet201_without_crop'], fontsize=18,  loc='lower right')

a[1].plot(acc_val_densenet201, '-o', markersize=10)
a[1].plot(acc_old_val_densenet201, '-*', markersize=10)
a[1].set_title('Model Validation Accuracy DenseNet201', fontsize=18)
a[1].set_ylabel('val_accuracy', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['densenet201_with_crop', 'densenet201_without_crop'], fontsize=18,  loc='lower right')
plt.show()

# %%
print(max(acc_train_densenet201))
print(max(acc_old_train_densenet201))
print(max(acc_val_densenet201))
print(max(acc_old_val_densenet201))
print(max(acc_adas_train_densenet201))
print(max(acc_adas_val_densenet201))
# Out:
# 0.998769987699877
# 0.998769987699877
# 0.941422594641043
# 0.9163179926293664
# 1.0
# 0.9539748929035714

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(loss_train_densenet201, '-o', markersize=10)
a[0].plot(loss_old_train_densenet201, '-*', markersize=10)
a[0].set_title('Model Train Loss DenseNet201', fontsize=18)
a[0].set_ylabel('loss', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['densenet201_with_crop', 'densenet201_without_crop'], fontsize=18,  loc='best')

a[1].plot(loss_val_densenet201, '-o', markersize=10)
a[1].plot(loss_old_val_densenet201, '-*', markersize=10)
a[1].set_title('Model Validation Loss DenseNet201', fontsize=18)
a[1].set_ylabel('val_loss', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['densenet201_with_crop', 'densenet201_without_crop'], fontsize=18,  loc='best')
plt.show()

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(acc_train_densenet201, '-o', markersize=10)
a[0].plot(acc_adas_train_densenet201, '-*', markersize=10)
a[0].set_title('Model Train Accuracy DenseNet201', fontsize=18)
a[0].set_ylabel('accuracy', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['densenet201_with_adam', 'densenet201_with_adas'], fontsize=18,  loc='best')

a[1].plot(acc_val_densenet201, '-o', markersize=10)
a[1].plot(acc_adas_val_densenet201, '-*', markersize=10)
a[1].set_title('Model Validation Accuracy DenseNet201', fontsize=18)
a[1].set_ylabel('val_accuracy', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['densenet201_with_adam', 'densenet201_with_adas'], fontsize=18,  loc='best')
plt.show()

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(loss_train_densenet201, '-o', markersize=10)
a[0].plot(loss_adas_train_densenet201, '-*', markersize=10)
a[0].set_title('Model Train Loss DenseNet201', fontsize=18)
a[0].set_ylabel('loss', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['densenet201_with_adam', 'densenet201_with_adas'], fontsize=18,  loc='best')

a[1].plot(loss_val_densenet201, '-o', markersize=10)
a[1].plot(loss_adas_val_densenet201, '-*', markersize=10)
a[1].set_title('Model Validation Loss DenseNet201', fontsize=18)
a[1].set_ylabel('val_loss', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['densenet201_with_adam', 'densenet201_with_adas'], fontsize=18,  loc='best')
plt.show()

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(acc_train_resnet152v2, '-o', markersize=10)
a[0].plot(acc_old_train_resnet152v2, '-*', markersize=10)
a[0].set_title('Model Train Accuracy Resnet152v2', fontsize=18)
a[0].set_ylabel('accuracy', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['Resnet152v2_with_crop', 'Resnet152v2_without_crop'], fontsize=18,  loc='best')

a[1].plot(acc_val_resnet152v2, '-o', markersize=10)
a[1].plot(acc_old_val_resnet152v2, '-*', markersize=10)
a[1].set_title('Model Validation Accuracy Resnet152v2', fontsize=18)
a[1].set_ylabel('val_accuracy', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['Resnet152v2_with_crop', 'Resnet152v2_without_crop'], fontsize=18,  loc='best')
plt.show()

# %%
print(max(acc_train_resnet152v2))
print(max(acc_old_train_resnet152v2))
print(max(acc_val_resnet152v2))
print(max(acc_old_val_resnet152v2))
print(max(acc_adas_train_resnet152v2))
print(max(acc_adas_val_resnet152v2))
# Out:
# 1.0
# 1.0
# 0.9330543935548311
# 0.9288702928870293
# 1.0
# 0.9497907949790795

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(loss_train_resnet152v2, '-o', markersize=10)
a[0].plot(loss_old_train_resnet152v2, '-*', markersize=10)
a[0].set_title('Model Train Loss Resnet152v2', fontsize=18)
a[0].set_ylabel('loss', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['Resnet152v2_with_crop', 'Resnet152v2_without_crop'], fontsize=18,  loc='best')

a[1].plot(loss_val_resnet152v2, '-o', markersize=10)
a[1].plot(loss_old_val_resnet152v2, '-*', markersize=10)
a[1].set_title('Model Validation Loss Resnet152v2', fontsize=18)
a[1].set_ylabel('val_loss', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['Resnet152v2_with_crop', 'Resnet152v2_without_crop'], fontsize=18,  loc='best')
plt.show()

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(acc_train_resnet152v2, '-o', markersize=10)
a[0].plot(acc_adas_train_resnet152v2, '-*', markersize=10)
a[0].set_title('Model Train Accuracy Resnet152v2', fontsize=18)
a[0].set_ylabel('accuracy', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['Resnet152v2_with_adam', 'Resnet152v2_with_adas'], fontsize=18,  loc='best')

a[1].plot(acc_val_resnet152v2, '-o', markersize=10)
a[1].plot(acc_adas_val_resnet152v2, '-*', markersize=10)
a[1].set_title('Model Validation Accuracy Resnet152v2', fontsize=18)
a[1].set_ylabel('val_accuracy', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['Resnet152v2_with_adam', 'Resnet152v2_with_adas'], fontsize=18,  loc='best')
plt.show()

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(loss_train_resnet152v2, '-o', markersize=10)
a[0].plot(loss_adas_train_resnet152v2, '-*', markersize=10)
a[0].set_title('Model Train Loss Resnet152v2', fontsize=18)
a[0].set_ylabel('loss', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['Resnet152v2_with_adam', 'Resnet152v2_with_adas'], fontsize=18,  loc='best')

a[1].plot(loss_val_resnet152v2, '-o', markersize=10)
a[1].plot(loss_adas_val_resnet152v2, '-*', markersize=10)
a[1].set_title('Model Validation Loss Resnet152v2', fontsize=18)
a[1].set_ylabel('val_loss', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['Resnet152v2_with_adam', 'Resnet152v2_with_adas'], fontsize=18,  loc='best')
plt.show()

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(acc_train_mobilenet_v3, '-o', markersize=10)
a[0].plot(acc_old_train_mobilenet_v3, '-*', markersize=10)
a[0].set_title('Model Train Accuracy Mobilenet_v3', fontsize=18)
a[0].set_ylabel('accuracy', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['mobilenet_v3_with_crop', 'mobilenet_v3_without_crop'], fontsize=18,  loc='best')

a[1].plot(acc_val_mobilenet_v3, '-o', markersize=10)
a[1].plot(acc_old_val_mobilenet_v3, '-*', markersize=10)
a[1].set_title('Model Validation Accuracy Mobilenet_v3', fontsize=18)
a[1].set_ylabel('val_accuracy', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['mobilenet_v3_with_crop', 'mobilenet_v3_without_crop'], fontsize=18,  loc='best')
plt.show()

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(acc_train_mobilenet_v3, '-o', markersize=10)
a[0].plot(acc_adas_train_mobilenet_v3, '-*', markersize=10)
a[0].set_title('Model Train Accuracy Mobilenet_v3', fontsize=18)
a[0].set_ylabel('accuracy', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['mobilenet_v3_with_adam', 'mobilenet_v3_with_adas'], fontsize=18,  loc='best')

a[1].plot(acc_val_mobilenet_v3, '-o', markersize=10)
a[1].plot(acc_adas_val_mobilenet_v3, '-*', markersize=10)
a[1].set_title('Model Validation Accuracy Mobilenet_v3', fontsize=18)
a[1].set_ylabel('val_accuracy', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['mobilenet_v3_with_adam', 'mobilenet_v3_with_adas'], fontsize=18,  loc='best')
plt.show()

# %%
print(max(acc_train_mobilenet_v3))
print(max(acc_old_train_mobilenet_v3))
print(max(acc_val_mobilenet_v3))
print(max(acc_old_val_mobilenet_v3))
print(max(acc_adas_train_mobilenet_v3))
print(max(acc_adas_val_mobilenet_v3))
# Out:
# 0.997539975399754
# 0.996309963099631
# 0.9121338919615646
# 0.8870292894511044
# 1.0
# 0.9539748956468813

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(acc_train_vgg19, '-o', markersize=10)
a[0].plot(acc_old_train_vgg19, '-*', markersize=10)
a[0].set_title('Model Train Accuracy VGG19', fontsize=18)
a[0].set_ylabel('accuracy', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['vgg19_with_crop', 'vgg19_without_crop'], fontsize=18,  loc='best')

a[1].plot(acc_val_vgg19, '-o', markersize=10)
a[1].plot(acc_old_val_vgg19, '-*', markersize=10)
a[1].set_title('Model Validation Accuracy VGG19', fontsize=18)
a[1].set_ylabel('val_accuracy', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['vgg19_with_crop', 'vgg19_without_crop'], fontsize=18,  loc='best')
plt.show()

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(acc_train_vgg19, '-o', markersize=10)
a[0].plot(acc_adas_train_vgg19, '-*', markersize=10)
a[0].set_title('Model Train Accuracy VGG19', fontsize=18)
a[0].set_ylabel('accuracy', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['vgg19_with_adam', 'vgg19_with_adas'], fontsize=18,  loc='best')

a[1].plot(acc_val_vgg19, '-o', markersize=10)
a[1].plot(acc_adas_val_vgg19, '-*', markersize=10)
a[1].set_title('Model Validation Accuracy VGG19', fontsize=18)
a[1].set_ylabel('val_accuracy', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['vgg19_with_adam', 'vgg19_with_adas'], fontsize=18,  loc='best')
plt.show()

# %%
print(max(acc_train_vgg19))
print(max(acc_old_train_vgg19))
print(max(acc_val_vgg19))
print(max(acc_old_val_vgg19))
print(max(acc_adas_train_vgg19))
print(max(acc_adas_val_vgg19))
# Out:
# 1.0
# 1.0
# 0.9288702931364211
# 0.8953974900385326
# 1.0
# 0.9456066945606695

# %%
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(acc_train_densenet201, '-o', markersize=10)
a[0].plot(acc_train_resnet152v2, '-*', markersize=10)
a[0].plot(acc_train_mobilenet_v3, '-s', markersize=10)
a[0].plot(acc_train_vgg19, '-^', markersize=10)
a[0].set_title('Model Train Accuracy', fontsize=18)
a[0].set_ylabel('accuracy', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['densenet201', 'resnet152v2', 'mobilenet_v3', 'vgg19'], fontsize=18,  loc='best')

a[1].plot(acc_val_densenet201, '-o', markersize=10)
a[1].plot(acc_val_resnet152v2, '-*', markersize=10)
a[1].plot(acc_val_mobilenet_v3, '-s', markersize=10)
a[1].plot(acc_val_vgg19, '-^', markersize=10)
a[1].set_title('Model Validation Accuracy', fontsize=18)
a[1].set_ylabel('val_accuracy', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['densenet201', 'resnet152v2', 'mobilenet_v3', 'vgg19'], fontsize=18,  loc='best')
plt.show()

# %%
#plot loss
#plot accuracy
fig,a =  plt.subplots(1, 2, figsize=(16,7))
a[0].plot(loss_train_densenet201, '-o', markersize=10)
a[0].plot(loss_train_resnet152v2, '-*', markersize=10)
a[0].plot(loss_train_mobilenet_v3, '-s', markersize=10)
a[0].plot(loss_train_vgg19, '-^', markersize=10)
a[0].set_title('Model Train Loss', fontsize=18)
a[0].set_ylabel('loss', fontsize=18)
a[0].set_xlabel('epoch', fontsize=18)
a[0].legend(['densenet201', 'resnet152v2', 'mobilenet_v3', 'vgg19'], fontsize=18,  loc='best')

a[1].plot(loss_val_densenet201, '-o', markersize=10)
a[1].plot(loss_val_resnet152v2, '-*', markersize=10)
a[1].plot(loss_val_mobilenet_v3, '-s', markersize=10)
a[1].plot(loss_val_vgg19, '-^', markersize=10)
a[1].set_title('Model Validation Loss', fontsize=18)
a[1].set_ylabel('val_loss', fontsize=18)
a[1].set_xlabel('epoch', fontsize=18)
a[1].legend(['densenet201', 'resnet152v2', 'mobilenet_v3', 'vgg19'], fontsize=18,  loc='best')
plt.show()

# %%
time_densenet201 = 2455.149657726288
time_old_densenet201 = 3165.957531929016
time_resnet150v2 = 2927.608421564102
time_old_resnet150v2 = 3639.3414146900177
time_mobilenet_v3 = 1398.2197120189667
time_old_mobilenet_v3 = 1869.1404542922974
time_vgg19 = 2691.850120306015
time_old_vgg19 = 3165.4450392723083

# time_inceptionresnetv2 = 0
# time_old_inceptionresnetv2 = 0

# %%
import matplotlib.pyplot as plt
# langs = ['densenet201_with_crop', 'densenet201_without_crop', 'resnet152v2_with_crop', 'resnet152v2_without_crop', 'inceptionresnetv2_with_crop', 'inceptionresnetv2_without_crop']
# values = [time_densenet201, time_old_densenet201, time_resnet150v2, time_old_resnet150v2, time_inceptionresnetv2, time_old_inceptionresnetv2]

langs = ['densenet201_with_crop', 'densenet201_without_crop', 'resnet152v2_with_crop', 'resnet152v2_without_crop','mobilenet_v3_with_crop', 'mobilenet_v3_without_crop', 'vgg19_with_crop', 'vgg19_without_crop']
values = [time_densenet201, time_old_densenet201, time_resnet150v2, time_old_resnet150v2, time_mobilenet_v3, time_old_mobilenet_v3, time_vgg19, time_old_vgg19]

plt.barh(langs, values)
plt.title('Time Training')
plt.xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %%
time_densenet201 = 2455.149657726288
time_adas_densenet201 = 2340.6594026088715
time_resnet150v2 = 3043.313593864441
time_adas_resnet150v2 = 3161.8986258506775
time_mobilenet_v3 = 1398.2197120189667
time_adas_mobilenet_v3 = 1234.8942470550537
time_vgg19 = 2691.850120306015
time_adas_vgg19 = 2447.799943447113

# %%
import matplotlib.pyplot as plt
# langs = ['densenet201_with_crop', 'densenet201_without_crop', 'resnet152v2_with_crop', 'resnet152v2_without_crop', 'inceptionresnetv2_with_crop', 'inceptionresnetv2_without_crop']
# values = [time_densenet201, time_old_densenet201, time_resnet150v2, time_old_resnet150v2, time_inceptionresnetv2, time_old_inceptionresnetv2]

langs = ['densenet201_with_crop_adam', 'densenet201_with_crop_adas', 'resnet152v2_with_crop_adam', 'resnet152v2_with_adas','mobilenet_v3_with_crop_adam', 'mobilenet_v3_with_crop_adas', 'vgg19_with_crop_adam', 'vgg19_with_crop_adas']
values = [time_densenet201, time_adas_densenet201, time_resnet150v2, time_adas_resnet150v2, time_mobilenet_v3, time_adas_mobilenet_v3, time_vgg19, time_adas_vgg19]

plt.barh(langs, values)
plt.title('Time Training')
plt.xlabel('Time(s)')
# Out:
# Text(0.5, 0, 'Time(s)')

# %%
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

#data
y = dict()
y[0] = [414, 121, 125]
y[1] = [399, 118, 130]

trace0 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[0],
    name='No',
    marker=dict(color='#33cc33'),
    opacity=0.7
)
trace1 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[1],
    name='Yes',
    marker=dict(color='#ff3300'),
    opacity=0.7
)
data = [trace0, trace1]
layout = go.Layout(
    title='Count of classes in each set',
    xaxis={'title': 'Set'},
    yaxis={'title': 'Count'}
)
fig = go.Figure(data, layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2904d1e9-d7c8-4441-a56a-6131f3476a9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2904d1e9-d7c8-4441-a56a-6131f3476a9a")) {
#                     Plotly.newPlot(
#                         '2904d1e9-d7c8-4441-a56a-6131f3476a9a',
# ...

# %%
from torchvision import datasets
from torchvision import transforms
from PIL import Image
from pathlib import Path
import torch, torchvision
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# # Specify a path
# # dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_denseNet201_27062021.pt'
# # dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_resnet152_28062021.pt'
# # dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_inceptionresnetv2_30062021.pt'
# dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_adas_denseNet201_30062021.pt'


# # Load
# # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# model_densenet = torch.load(dir_model, map_location='cpu')
# # model_densenet = model_densenet.to(device)
# model_densenet.eval()

# test_transform = transforms.Compose([
#         transforms.Resize(size=256),
#         transforms.CenterCrop(size=224),
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406],
#                              [0.229, 0.224, 0.225])
#     ])


# path = "/content/drive/My Drive/DetectBrainTumor/data_15062021/T2_Test"

# test_data = datasets.ImageFolder(path, transform=test_transform)  

# test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False)

# sum_no_yes = 0
# sum_no_no = 0
# sum_yes_yes = 0
# sum_yes_no = 0


# with torch.no_grad():
#     correct = 0
#     total = 0
#     for images, labels in test_loader:
#         images = images.to(device)
#         labels = labels.to(device)
#         outputs = model_densenet(images)
#         _, predicted = torch.max(outputs.data, 1)
#         if (labels[0] == 0):
#           if (predicted[0] == 0):
#             sum_no_yes =sum_no_yes + 1
#           else:
#             sum_no_no =sum_no_no + 1
#         if (labels[0] == 1):
#           if (predicted[0] == 1):
#             sum_yes_yes =sum_yes_yes + 1
#           else:
#             sum_yes_no =sum_yes_no + 1
#         # print(labels)
#         # print(outputs)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()
#     print(sum_yes_yes)
#     print(sum_yes_no)
#     print(sum_no_yes)
#     print(sum_no_no)
#     print('Test Accuracy of the model: {} %'.format(100 * correct / total))

# %%
# # Specify a path
# # dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_denseNet201_27062021.pt'
# # dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_resnet152_28062021.pt'
# # dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_inceptionresnetv2_30062021.pt'
# dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_adas_resnet152_30062021.pt'

# from torchvision import datasets
# from torchvision import transforms
# from PIL import Image
# from pathlib import Path
# import torch, torchvision

# # Load
# # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# model_densenet = torch.load(dir_model, map_location='cpu')
# # model_densenet = model_densenet.to(device)
# model_densenet.eval()

# test_transform = transforms.Compose([
#         transforms.Resize(size=256),
#         transforms.CenterCrop(size=224),
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406],
#                              [0.229, 0.224, 0.225])
#     ])


# path = "/content/drive/My Drive/DetectBrainTumor/data_15062021/T2_Test"

# test_data = datasets.ImageFolder(path, transform=test_transform)  

# test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False)

# sum_no_yes = 0
# sum_no_no = 0
# sum_yes_yes = 0
# sum_yes_no = 0


# with torch.no_grad():
#     correct = 0
#     total = 0
#     for images, labels in test_loader:
#         images = images.to(device)
#         labels = labels.to(device)
#         outputs = model_densenet(images)
#         _, predicted = torch.max(outputs.data, 1)
#         if (labels[0] == 0):
#           if (predicted[0] == 0):
#             sum_no_yes =sum_no_yes + 1
#           else:
#             sum_no_no =sum_no_no + 1
#         if (labels[0] == 1):
#           if (predicted[0] == 1):
#             sum_yes_yes =sum_yes_yes + 1
#           else:
#             sum_yes_no =sum_yes_no + 1
#         # print(labels)
#         # print(outputs)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()
#     print(sum_yes_yes)
#     print(sum_yes_no)
#     print(sum_no_yes)
#     print(sum_no_no)
#     print('Test Accuracy of the model: {} %'.format(100 * correct / total))

# %%
# !pip install cnn-finetune

# %%
# # Specify a path

# # dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_mobilenet_v3_04072021.pt'
# dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_adas_mobilenet_v3_07072021.pt'
# # dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch_data_old/model_mobilenet_v3_04072021.pt'
# from torchvision import datasets
# from torchvision import transforms
# from PIL import Image
# from pathlib import Path
# import torch, torchvision

# # Load
# # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# model_densenet = torch.load(dir_model, map_location='cpu')
# # model_densenet = model_densenet.to(device)
# model_densenet.eval()

# test_transform = transforms.Compose([
#         transforms.Resize(size=256),
#         transforms.CenterCrop(size=224),
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406],
#                              [0.229, 0.224, 0.225])
#     ])


# path = "/content/drive/My Drive/DetectBrainTumor/data_15062021/T2_Test"

# test_data = datasets.ImageFolder(path, transform=test_transform)  

# test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False)

# sum_no_yes = 0
# sum_no_no = 0
# sum_yes_yes = 0
# sum_yes_no = 0


# with torch.no_grad():
#     correct = 0
#     total = 0
#     for images, labels in test_loader:
#         images = images.to(device)
#         labels = labels.to(device)
#         outputs = model_densenet(images)
#         _, predicted = torch.max(outputs.data, 1)
#         if (labels[0] == 0):
#           if (predicted[0] == 0):
#             sum_no_yes =sum_no_yes + 1
#           else:
#             sum_no_no =sum_no_no + 1
#         if (labels[0] == 1):
#           if (predicted[0] == 1):
#             sum_yes_yes =sum_yes_yes + 1
#           else:
#             sum_yes_no =sum_yes_no + 1
#         # print(labels)
#         # print(outputs)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()
#     print(sum_yes_yes)
#     print(sum_yes_no)
#     print(sum_no_yes)
#     print(sum_no_no)
#     print('Test Accuracy of the model: {} %'.format(100 * correct / total))

# %%
# # Specify a path

# # dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_vgg19_02072021.pt'
# dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch/model_adas_vgg19_10072021.pt'
# # dir_model = '/content/drive/My Drive/DetectBrainTumor/model/pytorch_data_old/model_vgg19_02072021.pt'
# from torchvision import datasets
# from torchvision import transforms
# from PIL import Image
# from pathlib import Path
# import torch, torchvision

# # Load
# # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# model_densenet = torch.load(dir_model, map_location='cpu')
# # model_densenet = model_densenet.to(device)
# model_densenet.eval()

# test_transform = transforms.Compose([
#         transforms.Resize(size=256),
#         transforms.CenterCrop(size=224),
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406],
#                              [0.229, 0.224, 0.225])
#     ])


# path = "/content/drive/My Drive/DetectBrainTumor/data_15062021/T2_Test"

# test_data = datasets.ImageFolder(path, transform=test_transform)  

# test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False)

# sum_no_yes = 0
# sum_no_no = 0
# sum_yes_yes = 0
# sum_yes_no = 0


# with torch.no_grad():
#     correct = 0
#     total = 0
#     for images, labels in test_loader:
#         images = images.to(device)
#         labels = labels.to(device)
#         outputs = model_densenet(images)
#         _, predicted = torch.max(outputs.data, 1)
#         if (labels[0] == 0):
#           if (predicted[0] == 0):
#             sum_no_yes =sum_no_yes + 1
#           else:
#             sum_no_no =sum_no_no + 1
#         if (labels[0] == 1):
#           if (predicted[0] == 1):
#             sum_yes_yes =sum_yes_yes + 1
#           else:
#             sum_yes_no =sum_yes_no + 1
#         # print(labels)
#         # print(outputs)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()
#     print(sum_yes_yes)
#     print(sum_yes_no)
#     print(sum_no_yes)
#     print(sum_no_no)
#     print('Test Accuracy of the model: {} %'.format(100 * correct / total))

# %%
from sklearn.metrics import plot_confusion_matrix
import numpy as np


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize = 18)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45, fontsize = 18)
        plt.yticks(tick_marks, target_names, fontsize = 18)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black",
                     fontsize = 18)
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black",
                     fontsize = 18)


    plt.tight_layout()
    plt.ylabel('True label', fontsize = 18)
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass), fontsize = 18)
    plt.show()

# %%
plot_confusion_matrix(cm           = np.array([[ 122,  3],
                                              [  6,  124]]), 
                      normalize    = False,
                      target_names = ['YES', 'NO'],
                      title        = "Confusion Matrix DenseNet201",)

# %%
plot_confusion_matrix(cm           = np.array([[ 123,  2],
                                              [  6,  124]]), 
                      normalize    = False,
                      target_names = ['YES', 'NO'],
                      title        = "Confusion Matrix ResNet152v2",)

# %%
plot_confusion_matrix(cm           = np.array([[ 123,  2],
                                              [  4,  126]]), 
                      normalize    = False,
                      target_names = ['YES', 'NO'],
                      title        = "Confusion Matrix MobileNetV3",)

# %%
plot_confusion_matrix(cm           = np.array([[ 120,  5],
                                              [  8,  122]]), 
                      normalize    = False,
                      target_names = ['YES', 'NO'],
                      title        = "Confusion Matrix VGG19",)
